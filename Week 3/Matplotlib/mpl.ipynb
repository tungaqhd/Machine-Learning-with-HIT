# %%
import numpy as np
import pandas as pd
import folium as fo
import json
import requests

# %% [markdown]
# # Lấy Tọa Độ

# %%
def get_cor(city):
    Url = 'https://maps.googleapis.com/maps/api/geocode/json'
    Params ={'address': city, 'key' : 'AIzaSyCCEx6WdJ90TKGESd1qJzm93WdNTaAhKAk'}
    send = requests.get(url=Url, params=Params)
    data = send.json()
    # if data['status'] == 'ZERO_RESULTS' or data['results'][0]['address_components'][1]['short_name'] != 'SF':
        # return '*', '*'
    if data['status'] == 'ZERO_RESULTS' :
        return '*', '*'
    return data['results'][0]['geometry']['location']['lat'], data['results'][0]['geometry']['location']['lng']

# %%
data = pd.read_csv('Potentail_Bust_Stops.csv', encoding='latin-1')
data.columns = [i.lower().strip() for i in data.columns]

# %%
city1 = [data.street_one.unique()]
city2 = np.array(data.street_two.unique())

data['lat1'] = ''
data['lng1'] = ''
data['lat1'], data['lng1'] = get_cor('MISSION ST')

data['lat2'] = ''
data['lng2'] = ''

for i in city2:
    data.loc[data.street_two == i, 'lat2'], data.loc[data.street_two == i, 'lng2'] = get_cor(i)

# %%
data.to_csv('city_with_cor.csv')

# %%
data.head(20)
# Out:
#     Unnamed: 0  street_one         street_two      lat1        lng1  \
# 0            0  MISSION ST          ITALY AVE  37.73925 -122.423942
# 1            1  MISSION ST  NEW MONTGOMERY ST  37.73925 -122.423942
# 2            2  MISSION ST            01ST ST  37.73925 -122.423942
# 3            3  MISSION ST            20TH ST  37.73925 -122.423942
# 4            4  MISSION ST         FREMONT ST  37.73925 -122.423942
# 5            5  MISSION ST            13TH ST  37.73925 -122.423942
# 6            6  MISSION ST            ERIE ST  37.73925 -122.423942
# 7            7  MISSION ST           BEALE ST  37.73925 -122.423942
# 8            8  MISSION ST           FAIR AVE  37.73925 -122.423942
# 9            9  MISSION ST    SAINT MARYS AVE  37.73925 -122.423942
# 10          10  MISSION ST         SENECA AVE  37.73925 -122.423942
# 11          11  MISSION ST         ANTHONY ST  37.73925 -122.423942
# 12          12  MISSION ST     JESSIE EAST ST  37.73925 -122.423942
# ...

# %% [markdown]
# # Vẽ

# %%
data = pd.read_csv('city_with_cor.csv')
lat2= np.array(data.lat2)
lng2 = np.array(data.lng2)

# %%
world = fo.Map()

# %%
for i in range(len(lat2)):
    if lat2[i] != '*':
        fo.Marker([float(lat2[i]), float(lng2[i])]).add_to(world)

# %%
world
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
